# %% [markdown]
# ### Day 5: Cafeteria - Part 1

# %%
import re

with open("input5.txt") as file:
    ranges = [[int(id) for id in line.split("-")] for line in file if re.search("^.*-.*$", line.strip())]
    file.seek(0) # reset file pointer to start
    ids = [int(line.strip()) for line in file if re.search("^[0-9]+$", line.strip())]
    print(sum(1 for i in ids if any(r[0] <= i <= r[1] for r in ranges)))
# Out:
# 520

# %% [markdown]
# ### Day 5 - Part 2

# %% [markdown]
# first attempt (still contains a bug):

# %%
# def merge_ranges(r1, r2):
#     # consider a pair (start1, end1) and (start2, end2)
#     start1, end1 = r1
#     start2, end2 = r2
#     if start2 <= end1: # -> new start is start1
#         new_pair = [start1, max(end1,end2)]
#         return [new_pair]
#     else:
#         return [r1, r2] # Add both ranges back to the list

# updated = True
# while(updated):
#     updated = False # default: no updates happened yet
#     ranges = sorted(ranges, key=lambda x: x[0]) # sort by first id in each range
#     new_ranges = []
#     for r1, r2 in zip(ranges[::2], ranges[1::2]):
#         new_ranges += merge_ranges(r1, r2)
        
#     if len(ranges) % 2 != 0: # include the last unpaired element (if odd list)
#         new_ranges += merge_ranges(new_ranges.pop(-1), ranges[-1])

#     updated = len(new_ranges) != len(ranges)
    
#     ranges = new_ranges

# print([f"{start}-{end}" for (start, end) in ranges])
# print([end-start+1 for (start, end) in ranges])
# print(sum([(end-start)+1 for (start, end) in ranges]))
# Out:
# ['1586556133303-7804660665544', '10816561213024-17403288358828', '17403288358829-17403288358829', '22690003965833-27712728684461', '32602693579885-36885332659662', '42014003689388-44674834906409', '44674834906411-47998174838355', '51361204564916-57266618200157', '62323722432130-62323722432130', '62323722432130-66925241802374', '70501459498272-72081372974350', '71750732200219-73973002417526', '73568680644071-76027589553678', '75624783350778-78029746812084', '77505512096184-80206085949593', '83843340646406-83843340646406', '83843340646407-89877131953568', '90685402693099-91326282360805', '91607083862837-92258586051040', '92550120466026-93656142653628', '93278418174390-94055622593837', '94055622593837-94633294496134', '94327557076326-94792660654059', '94792660654059-95634958254905', '95634958254905-96297636385592', '95634958254905-95869328366402', '95869328366402-96297636385592', '96066694586475-96678037614080', '99467252078874-99662196705178', '101106073399710-108513090450650', '111706411681775-114670417328923', '114670417328924-119948249875901', '121982389279433-128962889211269', '132857122655757-138938671711249', '138938671711249-138938671711249', '142701989560555-149789254811763', '150870242160173-151671240285641', '150870242160173-151357843823034', '151357843823034-151671240285641', '152187819441392-152943176647959', '152943176647959-153165142076645', '153372607467265-154133730607957', '153372607467265-153655103744779', '153655103744779-154342975245442', '153989440562345-154342975245442', '154878689699307-155628311369459', '155472407501263-155852116431845', '155852116431845-156113791997404', '156113791997404-156454682734839', '157240109785436-158035203066734', '159385589208834-159677079847353', '159677079847353-160153050104113', '161584196527025-161584196527025', '161584196527025-169601317327971', '172002071120812-179067001590563', '179067001590564-179067001590564', '181610633794455-186973892121936', '192420278533129-199794315561836', '201251133948865-204012272920748', '203458381911153-205690552983855', '205197819894814-207722528284919', '207377430859253-209792952713581', '209233548734068-210669148874993', '213248042286677-215585625144687', '215585625144688-219093582316167', '224601031843196-224601031843196', '224601031843197-227676600861532', '234720803363794-239280893490085', '242837457497041-247076839433437', '247076839433439-249549980310650', '254841833346550